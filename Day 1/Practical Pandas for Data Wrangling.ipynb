# %% [markdown]
# # Practical Pandas for Data Wrangling
# ## Objectives
# - read data using Pandas
# - explore and analyze the data
# - apply transformations to the data

# %% [markdown]
# # [10] Basic Mechanics of Pandas
# Let's get familiar with the basic mechanics of the Pandas library.

# %%
url = "https://s3.amazonaws.com/python-level-2/sales-funnel.csv"

# %%
import pandas as pd

# %%
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won

# %% [markdown]
# **Let's see what columns are available.**

# %%
df.columns
# Out:
# Index(['Account', 'Name', 'Rep', 'Manager', 'Product', 'Quantity', 'Price',
#        'Status'],
#       dtype='object')

# %% [markdown]
# **Let's examine the beginning (head) and end (tail) of the data set**

# %%
df.tail(3)
# Out:
#     Account         Name         Rep        Manager  Product  Quantity  \
# 14   688981  Keeling LLC  Wendy Yule  Fred Anderson      CPU         5
# 15   729833    Koepp Ltd  Wendy Yule  Fred Anderson      CPU         2
# 16   729833    Koepp Ltd  Wendy Yule  Fred Anderson  Monitor         2
#
#      Price     Status
# 14  100000        won
# 15   65000   declined
# 16    5000  presented

# %% [markdown]
# **Let's examine the data types in this data set**

# %%
df.dtypes
# Out:
# Account      int64
# Name        object
# Rep         object
# Manager     object
# Product     object
# Quantity     int64
# Price        int64
# Status      object
# dtype: object

# %% [markdown]
# **Let's check out descriptive statistics**

# %%
df.describe()
# Out:
#              Account   Quantity          Price
# count      17.000000  17.000000      17.000000
# mean   462254.235294   1.764706   30705.882353
# std    259093.442862   1.032558   28444.605609
# min    141962.000000   1.000000    5000.000000
# 25%    218895.000000   1.000000    7000.000000
# 50%    412290.000000   2.000000   30000.000000
# 75%    714466.000000   2.000000   40000.000000
# max    740150.000000   5.000000  100000.000000

# %%
df.describe([.1, .3, .5, .7, .9])
# Out:
#              Account   Quantity          Price
# count      17.000000  17.000000      17.000000
# mean   462254.235294   1.764706   30705.882353
# std    259093.442862   1.032558   28444.605609
# min    141962.000000   1.000000    5000.000000
# 10%    156782.400000   1.000000    5000.000000
# 30%    235254.200000   1.000000    9400.000000
# 50%    412290.000000   2.000000   30000.000000
# 70%    714466.000000   2.000000   36000.000000
# 90%    732919.800000   2.400000   65000.000000
# max    740150.000000   5.000000  100000.000000

# %%
df.describe(include='all')
# Out:
#               Account             Name           Rep       Manager Product  \
# count       17.000000               17            17            17      17
# unique            NaN               12             5             2       4
# top               NaN  Trantow-Barrows  Craig Booker  Debra Henley     CPU
# freq              NaN                3             4             9       9
# mean    462254.235294              NaN           NaN           NaN     NaN
# std     259093.442862              NaN           NaN           NaN     NaN
# min     141962.000000              NaN           NaN           NaN     NaN
# 25%     218895.000000              NaN           NaN           NaN     NaN
# 50%     412290.000000              NaN           NaN           NaN     NaN
# 75%     714466.000000              NaN           NaN           NaN     NaN
# max     740150.000000              NaN           NaN           NaN     NaN
#
#          Quantity          Price     Status
# count   17.000000      17.000000         17
# unique        NaN            NaN          4
# top           NaN            NaN  presented
# freq          NaN            NaN          6
# mean     1.764706   30705.882353        NaN
# std      1.032558   28444.605609        NaN
# min      1.000000    5000.000000        NaN
# 25%      1.000000    7000.000000        NaN
# 50%      2.000000   30000.000000        NaN
# 75%      2.000000   40000.000000        NaN
# max      5.000000  100000.000000        NaN

# %% [markdown]
# # [30] Filtering
# One of the main things we'll do on our data set is filter to the records that are relevant, where the definition of what is relevant depends on the problem we are trying to solve.

# %%
df.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won

# %%
df.iloc[:8, :3]
# Out:
#    Account                          Name            Rep
# 0   714466               Trantow-Barrows   Craig Booker
# 1   714466               Trantow-Barrows   Craig Booker
# 2   714466               Trantow-Barrows   Craig Booker
# 3   737550  Fritsch, Russel and Anderson   Craig Booker
# 4   146832                  Kiehn-Spinka  Daniel Hilton
# 5   218895                     Kulas Inc  Daniel Hilton
# 6   218895                     Kulas Inc  Daniel Hilton
# 7   412290                 Jerde-Hilpert     John Smith

# %%
df[["Name", "Rep"]].head()
# Out:
#                            Name            Rep
# 0               Trantow-Barrows   Craig Booker
# 1               Trantow-Barrows   Craig Booker
# 2               Trantow-Barrows   Craig Booker
# 3  Fritsch, Russel and Anderson   Craig Booker
# 4                  Kiehn-Spinka  Daniel Hilton

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[df['Status']  == 'won']
# Out:
#     Account                         Name            Rep        Manager  \
# 4    146832                 Kiehn-Spinka  Daniel Hilton   Debra Henley
# 9    141962                   Herman LLC    Cedric Moss  Fred Anderson
# 13   307599  Kassulke, Ondricka and Metz     Wendy Yule  Fred Anderson
# 14   688981                  Keeling LLC     Wendy Yule  Fred Anderson
#
#         Product  Quantity   Price Status
# 4           CPU         2   65000    won
# 9           CPU         2   65000    won
# 13  Maintenance         3    7000    won
# 14          CPU         5  100000    won

# %%
df['Status']  == 'won'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13     True
# 14     True
# 15    False
# 16    False
# Name: Status, dtype: bool

# %% [markdown]
# ## Exercise
# How many accounts have a price greater than $12,000?

# %%
df[df['Price'] > 12000]
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 14   688981                   Keeling LLC     Wendy Yule  Fred Anderson
# 15   729833                     Koepp Ltd     Wendy Yule  Fred Anderson
#
#    Product  Quantity   Price     Status
# 0      CPU         1   30000  presented
# 3      CPU         1   35000   declined
# 4      CPU         2   65000        won
# 5      CPU         2   40000    pending
# 8      CPU         1   35000   declined
# 9      CPU         2   65000        won
# 10     CPU         1   30000  presented
# 14     CPU         5  100000        won
# 15     CPU         2   65000   declined

# %%
df[df.Price > 12000][:3]
# Out:
#    Account                          Name            Rep       Manager Product  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley     CPU
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley     CPU
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley     CPU
#
#    Quantity  Price     Status
# 0         1  30000  presented
# 3         1  35000   declined
# 4         2  65000        won

# %% [markdown]
# **Let's see how we get the maximum value of a certain column.**
#
# ## https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html

# %%
df['Quantity'].max()
# Out:
# 5

# %% [markdown]
# ## Exercise
# What is the minimum contract price? What is the mean? And the standard deviation?

# %%
df.Price.min()
# Out:
# 5000

# %%
df.Price.std()
# Out:
# 28444.605608714177

# %%
df.Price.mean()
# Out:
# 30705.882352941175

# %% [markdown]
# **Let's see how we can combine Boolean Masks to filter on multiple criteria.**

# %%
status_won = df['Status'] == 'won'

# %% [markdown]
# **Let's see what the result of this operation is...**

# %%
status_won
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13     True
# 14     True
# 15    False
# 16    False
# Name: Status, dtype: bool

# %%
product_cpu = df['Product'] == 'CPU'

# %%
df[status_won & product_cpu]
# Out:
#     Account          Name            Rep        Manager Product  Quantity  \
# 4    146832  Kiehn-Spinka  Daniel Hilton   Debra Henley     CPU         2
# 9    141962    Herman LLC    Cedric Moss  Fred Anderson     CPU         2
# 14   688981   Keeling LLC     Wendy Yule  Fred Anderson     CPU         5
#
#      Price Status
# 4    65000    won
# 9    65000    won
# 14  100000    won

# %% [markdown]
# **As an aside, there are many useful series methods, for example `unique`**

# %%
df['Product'].unique()
# Out:
# array(['CPU', 'Software', 'Maintenance', 'Monitor'], dtype=object)

# %% [markdown]
# ## Exercise
# What is the total `Amount` (hint: you'll need to create a new column) for contracts that match following criteria
#
# ```
# product either CPU or Software or Maintenance
# manager is either Fred or Debra
# ```
#
# Amount = Quantity * Price

# %%
df['Amount'] = df['Quantity'] * df['Price']

# %%
is_desired_prod = (df['Product'] == 'CPU') | (df['Product'] == 'Software') | (df['Product'] == 'Maintenance')

# %%
is_prod = df.Product.isin(['CPU', 'Software', 'Maintenance'])
is_manager = df.Manager.isin(['Debra Henley', 'Fred Anderson'])
df[is_prod & is_manager]['Amount'].sum()
# Out:
# 1176000

# %% [markdown]
# # [20] Aggregating Data / Pivot Tables

# %% [markdown]
# **Sometimes it's useful to get an aggregate view of our data.**
#
# ## https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html
#
# Let's step through the following together!

# %% [markdown]
# **Let's pivot on one index.**

# %%
pd.pivot_table(df, index='Manager')
# Out:
#                      Account         Amount         Price  Quantity
# Manager
# Debra Henley   513112.222222   38888.888889  26111.111111  1.444444
# Fred Anderson  405039.000000  104500.000000  35875.000000  2.125000

# %% [markdown]
# **Let's pivot on multiple indices**

# %%
pd.pivot_table(df, index=['Rep', 'Manager'])
# Out:
#                               Account         Amount         Price  Quantity
# Rep           Manager
# Cedric Moss   Fred Anderson  196016.5   43750.000000  27500.000000  1.250000
# Craig Booker  Debra Henley   720237.0   21250.000000  20000.000000  1.250000
# Daniel Hilton Debra Henley   194874.0   73333.333333  38333.333333  1.666667
# John Smith    Debra Henley   576220.0   22500.000000  20000.000000  1.500000
# Wendy Yule    Fred Anderson  614061.5  165250.000000  44250.000000  3.000000

# %% [markdown]
# **Let's reverse those indices**

# %%
pd.pivot_table(df, index=['Manager', 'Rep'])
# Out:
#                               Account         Amount         Price  Quantity
# Manager       Rep
# Debra Henley  Craig Booker   720237.0   21250.000000  20000.000000  1.250000
#               Daniel Hilton  194874.0   73333.333333  38333.333333  1.666667
#               John Smith     576220.0   22500.000000  20000.000000  1.500000
# Fred Anderson Cedric Moss    196016.5   43750.000000  27500.000000  1.250000
#               Wendy Yule     614061.5  165250.000000  44250.000000  3.000000

# %% [markdown]
# **Let's specify which values we care about**

# %%
pd.pivot_table(
    df,
    index=['Manager', 'Rep'],
    values=['Amount'],
    columns=['Status'],
    fill_value=0,
    aggfunc='sum'
)
# Out:
#                               Amount
# Status                      declined pending presented     won
# Manager       Rep
# Debra Henley  Craig Booker     35000   10000     40000       0
#               Daniel Hilton        0   80000     10000  130000
#               John Smith       35000   10000         0       0
# Fred Anderson Cedric Moss          0    5000     40000  130000
#               Wendy Yule      130000       0     10000  521000

# %% [markdown]
# **Let's specify which columns we want broken down**

# %% [markdown]
# **Let's specify how we want the values to be aggregated (`aggfunc`)**

# %%
pd.pivot_table(
    df,
    index=['Manager', 'Rep'],
    values=['Amount', 'Price'],
    columns=['Status'],
    fill_value=0,
    aggfunc={'Amount': 'sum', 'Price': 'mean'}
)
# Out:
#                               Amount                              Price  \
# Status                      declined pending presented     won declined
# Manager       Rep
# Debra Henley  Craig Booker     35000   10000     40000       0    35000
#               Daniel Hilton        0   80000     10000  130000        0
#               John Smith       35000   10000         0       0    35000
# Fred Anderson Cedric Moss          0    5000     40000  130000        0
#               Wendy Yule      130000       0     10000  521000    65000
#
#
# Status                      pending presented    won
# Manager       Rep
# Debra Henley  Craig Booker     5000     20000      0
#               Daniel Hilton   40000     10000  65000
#               John Smith       5000         0      0
# Fred Anderson Cedric Moss      5000     20000  65000
#               Wendy Yule          0      5000  53500

# %% [markdown]
# **Let's fill N/A values**

# %% [markdown]
# **Let's get subtotals**

# %% [markdown]
# ## Exercise
# Create our own pivots that you think will be useful and then let's share and discuss.

# %%
pd.pivot_table(df, 
               index=['Rep', 'Name', 'Product'], 
               values=['Amount', 'Quantity'], 
               columns=['Status'], 
               fill_value=0,
               aggfunc={'Quantity': 'sum', 'Amount': 'sum'},
               margins=True,
               margins_name='Totals'
              )
# Out:
#                                                          Amount          \
# Status                                                 declined pending
# Rep           Name                         Product
# Cedric Moss   Herman LLC                   CPU                0       0
#               Purdy-Kunde                  CPU                0       0
#               Stokes LLC                   Maintenance        0    5000
#                                            Software           0       0
# Craig Booker  Fritsch, Russel and Anderson CPU            35000       0
#               Trantow-Barrows              CPU                0       0
#                                            Maintenance        0   10000
#                                            Software           0       0
# Daniel Hilton Kiehn-Spinka                 CPU                0       0
#               Kulas Inc                    CPU                0   80000
#                                            Software           0       0
# John Smith    Barton LLC                   CPU            35000       0
#               Jerde-Hilpert                Maintenance        0   10000
# Wendy Yule    Kassulke, Ondricka and Metz  Maintenance        0       0
#               Keeling LLC                  CPU                0       0
#               Koepp Ltd                    CPU           130000       0
#                                            Monitor            0       0
# Totals                                                   200000  105000
#
#                                                                           \
# Status                                                 presented     won
# Rep           Name                         Product
# Cedric Moss   Herman LLC                   CPU                 0  130000
#               Purdy-Kunde                  CPU             30000       0
#               Stokes LLC                   Maintenance         0       0
#                                            Software        10000       0
# Craig Booker  Fritsch, Russel and Anderson CPU                 0       0
#               Trantow-Barrows              CPU             30000       0
#                                            Maintenance         0       0
#                                            Software        10000       0
# Daniel Hilton Kiehn-Spinka                 CPU                 0  130000
#               Kulas Inc                    CPU                 0       0
#                                            Software        10000       0
# John Smith    Barton LLC                   CPU                 0       0
#               Jerde-Hilpert                Maintenance         0       0
# Wendy Yule    Kassulke, Ondricka and Metz  Maintenance         0   21000
#               Keeling LLC                  CPU                 0  500000
#               Koepp Ltd                    CPU                 0       0
#                                            Monitor         10000       0
# Totals                                                    100000  781000
#
#                                                                 Quantity  \
# Status                                                   Totals declined
# Rep           Name                         Product
# Cedric Moss   Herman LLC                   CPU           130000        0
#               Purdy-Kunde                  CPU            30000        0
#               Stokes LLC                   Maintenance     5000        0
#                                            Software       10000        0
# Craig Booker  Fritsch, Russel and Anderson CPU            35000        1
#               Trantow-Barrows              CPU            30000        0
#                                            Maintenance    10000        0
#                                            Software       10000        0
# Daniel Hilton Kiehn-Spinka                 CPU           130000        0
#               Kulas Inc                    CPU            80000        0
#                                            Software       10000        0
# John Smith    Barton LLC                   CPU            35000        1
#               Jerde-Hilpert                Maintenance    10000        0
# Wendy Yule    Kassulke, Ondricka and Metz  Maintenance    21000        0
#               Keeling LLC                  CPU           500000        0
#               Koepp Ltd                    CPU           130000        2
#                                            Monitor        10000        0
# Totals                                                  1186000        4
#
#                                                                               \
# Status                                                 pending presented won
# Rep           Name                         Product
# Cedric Moss   Herman LLC                   CPU               0         0   2
#               Purdy-Kunde                  CPU               0         1   0
#               Stokes LLC                   Maintenance       1         0   0
#                                            Software          0         1   0
# Craig Booker  Fritsch, Russel and Anderson CPU               0         0   0
#               Trantow-Barrows              CPU               0         1   0
#                                            Maintenance       2         0   0
#                                            Software          0         1   0
# Daniel Hilton Kiehn-Spinka                 CPU               0         0   2
#               Kulas Inc                    CPU               2         0   0
#                                            Software          0         1   0
# John Smith    Barton LLC                   CPU               0         0   0
#               Jerde-Hilpert                Maintenance       2         0   0
# Wendy Yule    Kassulke, Ondricka and Metz  Maintenance       0         0   3
#               Keeling LLC                  CPU               0         0   5
#               Koepp Ltd                    CPU               0         0   0
#                                            Monitor           0         2   0
# Totals                                                       7         7  12
#
#
# Status                                                 Totals
# Rep           Name                         Product
# Cedric Moss   Herman LLC                   CPU              2
#               Purdy-Kunde                  CPU              1
#               Stokes LLC                   Maintenance      1
#                                            Software         1
# Craig Booker  Fritsch, Russel and Anderson CPU              1
#               Trantow-Barrows              CPU              1
#                                            Maintenance      2
#                                            Software         1
# Daniel Hilton Kiehn-Spinka                 CPU              2
#               Kulas Inc                    CPU              2
#                                            Software         1
# John Smith    Barton LLC                   CPU              1
#               Jerde-Hilpert                Maintenance      2
# Wendy Yule    Kassulke, Ondricka and Metz  Maintenance      3
#               Keeling LLC                  CPU              5
#               Koepp Ltd                    CPU              2
#                                            Monitor          2
# Totals                                                     30

# %%
pd.pivot_table(df,
               index=['Product'],
               values=['Quantity', 'Price'],
               columns =['Rep'],
               fill_value = 0,
               aggfunc={'Quantity':'sum', 'Price':'mean'}
)
# Out:
#                   Price                                                   \
# Rep         Cedric Moss Craig Booker Daniel Hilton John Smith Wendy Yule
# Product
# CPU               47500        32500         52500      35000      82500
# Maintenance        5000         5000             0       5000       7000
# Monitor               0            0             0          0       5000
# Software          10000        10000         10000          0          0
#
#                Quantity
# Rep         Cedric Moss Craig Booker Daniel Hilton John Smith Wendy Yule
# Product
# CPU                   3            2             4          1          7
# Maintenance           1            2             0          2          3
# Monitor               0            0             0          0          2
# Software              1            1             1          0          0

# %% [markdown]
# ### Mini-Exercise
# Get total amount per rep, ONLY considering the contracts that are NOT declined.

# %%
pd.pivot_table(df[df.Status != 'declined'], index='Rep', values='Amount', aggfunc='sum')
# Out:
#                Amount
# Rep
# Cedric Moss    175000
# Craig Booker    50000
# Daniel Hilton  220000
# John Smith      10000
# Wendy Yule     531000

# %% [markdown]
# # [60] Applying Transformations to the Data
# ## This is the "fun" part (it can be!) of data wrangling

# %%
df.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status  Amount
# 0          CPU         1  30000  presented   30000
# 1     Software         1  10000  presented   10000
# 2  Maintenance         2   5000    pending   10000
# 3          CPU         1  35000   declined   35000
# 4          CPU         2  65000        won  130000

# %% [markdown]
# **Let's look at Python dictionaries.**
# Let's make note of the syntax.

# %%
course_catalog = {
    'AST101': 'Astronomy 101: The Solar System',
    'MATH101': 'Pre-Algebra',
    'ENG304': 'Shakespeare and Donne'
}

# %%
course_catalog['AST101']
# Out:
# 'Astronomy 101: The Solar System'

# %%
course_catalog['AST102']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-a22480e33515> in <module>
# ----> 1 course_catalog['AST102']
#
# KeyError: 'AST102'

# %%
'ENG304' in course_catalog
# Out:
# True

# %%
'Pre-Algebra' in course_catalog.items()
# Out:
# False

# %%
course_catalog.keys()
# Out:
# dict_keys(['AST101', 'MATH101', 'ENG304'])

# %%
course_catalog.values()
# Out:
# dict_values(['Astronomy 101: The Solar System', 'Pre-Algebra', 'Shakespeare and Donne'])

# %%
course_catalog.items()
# Out:
# dict_items([('AST101', 'Astronomy 101: The Solar System'), ('MATH101', 'Pre-Algebra'), ('ENG304', 'Shakespeare and Donne')])

# %%
df.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status  Amount
# 0          CPU         1  30000  presented   30000
# 1     Software         1  10000  presented   10000
# 2  Maintenance         2   5000    pending   10000
# 3          CPU         1  35000   declined   35000
# 4          CPU         2  65000        won  130000

# %%
def double_val(value):
    return value * 2
    

df["high_quantity"] = df["Quantity"].apply(double_val)


df["high_quantity"] = df["Quantity"].apply(lambda val: val * 2)

# %%
df.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status  Amount  high_quantity
# 0          CPU         1  30000  presented   30000              2
# 1     Software         1  10000  presented   10000              2
# 2  Maintenance         2   5000    pending   10000              4
# 3          CPU         1  35000   declined   35000              2
# 4          CPU         2  65000        won  130000              4

# %%
CLIENT_CATEGORY_MAP = {
    'Trantow-Barrows': 'Accounting',
    'Fritsch, Russel and Anderson': 'Legal',
    'Kiehn-Spinka': 'Manufacturing',
    'Kulas Inc': 'Manufacturing',
    'Jerde-Hilpert': 'Accounting',
    'Barton LLC': 'Enterprise',
    'Herman LLC':  'Enterprise',
    'Purdy-Kunde': 'Legal',
    'Stokes LLC': 'Enterprise',
    'Kassulke, Ondricka and Metz': "Legal",
    'Koepp Ltd': 'Shipping',
    'Keeling LLC': "Enterprise"
    
}

# %% [markdown]
# **Let's create a new column based on the above mapping and call it "Client_Category**

# %%
df["Client_Category"] = df["Name"].apply(lambda val: CLIENT_CATEGORY_MAP[val])

# %%
df.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status  Amount  high_quantity  \
# 0          CPU         1  30000  presented   30000              2
# 1     Software         1  10000  presented   10000              2
# 2  Maintenance         2   5000    pending   10000              4
# 3          CPU         1  35000   declined   35000              2
# 4          CPU         2  65000        won  130000              4
#
#   Client_Category
# 0      Accounting
# 1      Accounting
# 2      Accounting
# 3           Legal
# 4   Manufacturing

# %% [markdown]
# **Now let's work with a different data set and keep practicing data munging!**

# %%
df = pd.read_csv(
    "https://raw.githubusercontent.com/suneel0101/lesson-plan/master/crunchbase_monthly_export.csv",
)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x89 in position 15: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-86-dcb992aa12e7> in <module>
# ----> 1 df = pd.read_csv(
#       2     "https://raw.githubusercontent.com/suneel0101/lesson-plan/master/crunchbase_monthly_export.csv",
#       3 )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     456
#     457     try:
# --> 458         data = parser.read(nrows)
#     459     finally:
#     460         parser.close()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1194     def read(self, nrows=None):
#    1195         nrows = _validate_integer("nrows", nrows)
# -> 1196         ret = self._engine.read(nrows)
#    1197
#    1198         # May alter columns / col_dict
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2153     def read(self, nrows=None):
#    2154         try:
# -> 2155             data = self._reader.read(nrows)
#    2156         except StopIteration:
#    2157             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x89 in position 15: invalid start byte

# %% [markdown]
# **What happened?**

# %%
df = pd.read_csv(
    "https://raw.githubusercontent.com/suneel0101/lesson-plan/master/crunchbase_monthly_export.csv",
    encoding='ISO-8859-1'
)

# %%
df.head()
# Out:
#                          permalink                name  \
# 0   /organization/canal-do-credito    Canal do Credito
# 1            /organization/waywire            #waywire
# 2  /organization/tv-communications  &TV Communications
# 3    /organization/rock-your-paper   'Rock' Your Paper
# 4   /organization/in-touch-network   (In)Touch Network
#
#                        homepage_url  \
# 0  http://www.canaldocredito.com.br
# 1            http://www.waywire.com
# 2             http://enjoyandtv.com
# 3      http://www.rockyourpaper.org
# 4     http://www.InTouchNetwork.com
#
#                                        category_list          market   \
# 0               |Credit|Technology|Services|Finance|          Credit
# 1         |Entertainment|Politics|Social Media|News|   Entertainment
# 2                                            |Games|           Games
# 3                             |Publishing|Education|       Education
# 4  |Electronics|Guides|Coffee|Restaurants|Music|i...            Apps
#
#    funding_total_usd      status country_code state_code          region  \
# 0            750,000         NaN          BRA        NaN  Rio de Janeiro
# 1          1,750,000    acquired          USA         NY   New York City
# 2          4,000,000   operating          USA         CA     Los Angeles
# 3             40,000   operating          EST        NaN         Tallinn
# 4          1,500,000   operating          GBR        NaN          London
#
#              city  funding_rounds founded_at founded_month founded_quarter  \
# 0  Belo Horizonte               1        NaN           NaN             NaN
# 1        New York               1     6/1/12       2012-06         2012-Q2
# 2     Los Angeles               2        NaN           NaN             NaN
# 3         Tallinn               1   10/26/12       2012-10         2012-Q4
# 4          London               1     4/1/11       2011-04         2011-Q2
#
#    founded_year first_funding_at last_funding_at  Unnamed: 18
# 0           NaN           1/1/10          1/1/10          NaN
# 1        2012.0          6/30/12         6/30/12          NaN
# 2           NaN           6/4/10         9/23/10          NaN
# 3        2012.0           8/9/12          8/9/12          NaN
# 4        2011.0           4/1/11          4/1/11          NaN

# %%
# Any issues?
df.dtypes
# Out:
# permalink               object
# name                    object
# homepage_url            object
# category_list           object
#  market                 object
#  funding_total_usd      object
# status                  object
# country_code            object
# state_code              object
# region                  object
# city                    object
# funding_rounds           int64
# founded_at              object
# founded_month           object
# founded_quarter         object
# founded_year           float64
# first_funding_at        object
# last_funding_at         object
# Unnamed: 18            float64
# dtype: object

# %%
df.columns
# Out:
# Index(['permalink', 'name', 'homepage_url', 'category_list', ' market ',
#        ' funding_total_usd ', 'status', 'country_code', 'state_code', 'region',
#        'city', 'funding_rounds', 'founded_at', 'founded_month',
#        'founded_quarter', 'founded_year', 'first_funding_at',
#        'last_funding_at', 'Unnamed: 18'],
#       dtype='object')

# %%
df.columns  = ['permalink', 'name', 'homepage_url', 'category_list', 'market',
       'funding_total_usd', 'status', 'country_code', 'state_code', 'region',
       'city', 'funding_rounds', 'founded_at', 'founded_month',
       'founded_quarter', 'founded_year', 'first_funding_at',
       'last_funding_at', 'Unnamed: 18']

# %% [markdown]
# ## Exercise
# - Get descriptive statistics
# - Look at datatypes, any issues?
# - Get unique values for each of the column and see what they are (in particular category_list, market, status, and region)

# %% [markdown]
# ## Exercise
# Write a function that takes a value like what we see in `funding_total_usd` and returns a numeric value. Call it `transform_funding_total`, for exampe:
#
# ```python
# def transform_funding_total(value):
#     # some logic
#     # transformed_value = ...
#     return transformed_value
# ```
#
# So that when it's called, it does the following:
#
# ```
# >>> transform_funding_total('1,230,200')
# 1230200
# ```

# %%
def clean_total(val):
    try:
        return float(val.replace(",", ""))
    except ValueError:
        pass

df['clean_funding_total'] = df['funding_total_usd'].apply(clean_total)

# %%
df['clean_funding_total'].describe()
# Out:
# count    3.754400e+04
# mean     1.800507e+07
# std      4.417086e+08
# min      3.500000e+01
# 25%      3.859800e+05
# 50%      2.000000e+06
# 75%      1.000000e+07
# max      7.879506e+10
# Name: clean_funding_total, dtype: float64

# %% [markdown]
# **Now let's apply it and transform the column in question**

# %% [markdown]
# ## Exercise (hint: Pivots)
# - What is the average number of funding rounds for companies in NYC?

# %% [markdown]
# ## Exercise
# What are the top 3 markets with the highest average funding total per company?

# %%
p_df = pd.pivot_table(df, index=['market'], values=['clean_funding_total'], fill_value=0)

# %%
p_df.sort_values('clean_funding_total', axis=0, ascending=False)[:3]
# Out:
#                     clean_funding_total
# market
#  Oil and Gas                824257670.0
#  Local Commerce             440500000.0
#  Natural Gas Uses           400000000.0
